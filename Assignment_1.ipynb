# %%
1. In the below elements which of them are values or an expression? eg:- values can be
integer or string and expressions will be mathematical operators.

* ---> expression
&#39;hello&#39;---> values
-87.8---> values
-  ---> expression
/  ----> expression
+  ----> expression
6  ----> values


2. What is the difference between string and variable?

Ans:  String:It simply represents text data and can include number ,letters,whitespaces or special charecter but should be in single or 
      double quote.Basically anything in single or double quote is a string('',"").
      eg:"Adidas"
        "123Toy"
        
     Variable:Variable is a name that represents a value stored in the computer's memory.
     It's a way to give a label or identifier to a value so that you can refer to and manipulate it later in your code.   
     eg: age=25
        name="touseef"
        
        

3. Describe three different data types.
#mentioning all data types for my future ref.
Ans:
Integer (int):Integers are whole numbers without any decimal point. They can be positive, negative, or zero.

Floating-Point (float):Floating-point numbers represent real numbers with a decimal point. They can represent both whole numbers
and fractions

String (str):
    
Strings represent sequences of characters. They are used to represent text-based data. Strings are enclosed in single ('') 
or double ("") quotes.

Boolean (bool):
    
Booleans represent two truth values: True and False.
    
    
List:
Lists are ordered collections of values, which can be of different data types. Lists are mutable, meaning their elements can be modified after creation. Lists are enclosed in square brackets and separated by commas. Examples: [1, 2, 3], ['apple', 'banana', 'cherry'].

Tuple:
    
Tuples are similar to lists but are immutable, meaning their elements cannot be changed after creation.
Tuples are often used for grouping related data. They are enclosed in parentheses and separated by commas.
Examples: (1, 2, 3), ('January', 31).

Dictionary:
    
Dictionaries store key-value pairs, where each value is associated with a unique key. 
Keys are typically strings, and values can be of different data types. Dictionaries are enclosed in curly braces
and consist of key-value pairs separated by colons. Examples: {'name': 'Alice', 'age': 25}.

Set:
    
Sets are unordered collections of unique elements. They are used to perform set operations like union, intersection, 
and difference. Sets are enclosed in curly braces or can be created using the set() constructor. Examples: {1, 2, 3}, set([3, 4, 5]).

NoneType (None):
None is a special data type representing the absence of a value. It's often used to indicate a lack of data 
or a default value. It is not the same as an empty string or zero. Example: None.




4. What is an expression made up of? What do all expressions do?

Ans:

An expression in programming is a combination of values, variables, operators, and function calls that can be evaluated
to produce a result. Expressions are the building blocks of programs and are used to perform operations and calculations.
They can represent computations, comparisons, assignments, and more.
An expression is typically made up of Values("hello"),Variables(),Operators and Function Calls like(len("Hello") or math.sqrt(25))


5. This assignment statements, like spam = 10. What is the difference between an expression and a statement?

Ans:

spam = 10 is an assignment statement. It assigns the value 10 to the variable spam.

Expression:
    
An expression is a combination of values, variables, operators, and function calls that can be evaluated to produce
a single value.

x = 5 + 3   # This is an expression that evaluates to 8
name = "Alice"   # This is an expression that evaluates to the string "Alice"

Statement:
    
A statement is a complete line of code that performs an action
Unlike expressions, statements don't necessarily result in a value. Instead, they are executed for their side effects,
such as modifying variables, controlling program flow, or interacting with external resources. Statements include assignments,
control structures (like loops and conditionals), function and method calls, and more.

x = 5   # This is an assignment statement
if x > 0:   # This is a conditional statement
    print("Positive")   # This is a print statement
    



6. After running the following code, what does the variable bacon contain?
bacon = 22
bacon + 1

Ans:

Bacon will hold value as 22.If we want to increase it by +1 then folowing code should be used.

bacon = 22
bacon = bacon + 1 

or

bacon = 22
bacon += 1 


7. What should the values of the following two terms be?
&#39;spam&#39; + &#39;spamspam&#39;
&#39;spam&#39; * 3

Ans:


&#39; is an HTML entity code that represents the single quotation mark character (').However it is not required in python.
We can directly use '' or "" quote.

+ is used for conacatenation

*3 is used repeat the word spam 3 times.

Result of line 1: 'spamspamspam'
Result of line 2: 'spamspamspam'




8. Why is eggs a valid variable name while 100 is invalid?

Ans:

It is because of naming convention used in python.100 is not a following valid naming convention.

Variable naming convention:
    
1.Variable names must start with a letter (a-z, A-Z) or an underscore (_).
2.The remaining characters in the variable name can be letters, underscores, or digits (0-9).
3.Variable names are case-sensitive, meaning myVariable and myvariable would be treated as two different variables.

9. What three functions can be used to get the integer, floating-point number, or string
version of a value?

Ans:

int(): This function is used to convert a value to an integer. It takes a numeric string or a floating-point number
as an argument and returns an integer version of that value.

# int_value = int("42")

float(): This function is used to convert a value to a floating-point number. 
It takes a numeric string or an integer as an argument and returns a floating-point version of that

# float_value = float("3.14")

str(): This function is used to convert a value to a string. It takes any data type as an argument
and returns a string representation of that value.Eg:

# str_value = str(42)



10. Why does this expression cause an error? How can you fix it?
&#39;I have eaten &#39; + 99 + &#39; burritos.&#39;

Ans:

The expression 'I have eaten ' + 99 + ' burritos.' causes an error because you are trying to concatenate a string
('I have eaten ') with an integer (99) directly using the + operator. In Python, you can concatenate strings together
using the + operator, but you cannot directly concatenate a string with an integer. You need to ensure that both operands
of the + operator are of the same data type.

To fix this, you can convert the integer 99 to a string using the str() function, and then perform the string concatenation:
    
result = 'I have eaten ' + str(99) + ' burritos.'
print(result)
